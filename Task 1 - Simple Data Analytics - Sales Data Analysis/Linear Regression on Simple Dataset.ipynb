# %% [markdown]
# #Linear Regression : Predicting Sales based on Advertising Spend

# %% [markdown]
# #Importing the Dataset

# %%
import pandas as pd
df=pd.read_csv('/content/Advertising Budget and Sales.csv')
df
# Out:
#      TV Ad Budget ($)  Radio Ad Budget ($)  Newspaper Ad Budget ($)  Sales ($)
# 0               230.1                 37.8                     69.2       22.1
# 1                44.5                 39.3                     45.1       10.4
# 2                17.2                 45.9                     69.3        9.3
# 3               151.5                 41.3                     58.5       18.5
# 4               180.8                 10.8                     58.4       12.9
# ..                ...                  ...                      ...        ...
# 195              38.2                  3.7                     13.8        7.6
# 196              94.2                  4.9                      8.1        9.7
# 197             177.0                  9.3                      6.4       12.8
# 198             283.6                 42.0                     66.2       25.5
# 199             232.1                  8.6                      8.7       13.4
#
# [200 rows x 4 columns]

# %% [markdown]
# #Checking for Null Values

# %%
df.isnull().sum()
# Out:
# TV Ad Budget ($)           0
# Radio Ad Budget ($)        0
# Newspaper Ad Budget ($)    0
# Sales ($)                  0
# dtype: int64

# %% [markdown]
# #Checking the Datatypes

# %%
df.dtypes
# Out:
# TV Ad Budget ($)           float64
# Radio Ad Budget ($)        float64
# Newspaper Ad Budget ($)    float64
# Sales ($)                  float64
# dtype: object

# %% [markdown]
# #Splitting to X features and y target variables

# %%
X=df.iloc[:,0:-1]
X
# Out:
#      TV Ad Budget ($)  Radio Ad Budget ($)  Newspaper Ad Budget ($)
# 0               230.1                 37.8                     69.2
# 1                44.5                 39.3                     45.1
# 2                17.2                 45.9                     69.3
# 3               151.5                 41.3                     58.5
# 4               180.8                 10.8                     58.4
# ..                ...                  ...                      ...
# 195              38.2                  3.7                     13.8
# 196              94.2                  4.9                      8.1
# 197             177.0                  9.3                      6.4
# 198             283.6                 42.0                     66.2
# 199             232.1                  8.6                      8.7
#
# [200 rows x 3 columns]

# %%
y=df.iloc[:,-1]
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales ($), Length: 200, dtype: float64

# %% [markdown]
# #Splitting to Train and Test Set

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=1)

# %% [markdown]
# #Building the Model

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #Predicting Using the Model

# %%
y_pred=model.predict(X_test)
y_pred
# Out:
# array([21.73577184, 16.45693776,  7.65993185, 17.89202679, 18.67730671,
#        23.86271904, 16.33623628, 13.45649226,  9.177296  , 17.36056228,
#        14.4677995 ,  9.85697601, 17.26057027, 16.71866935, 15.09530285,
#        15.58923732, 12.45188167, 17.27925151, 11.0944114 , 18.06889853,
#         9.33433055, 12.91345761,  8.7842804 , 10.46670654, 11.40303174,
#        15.03104665,  9.78479388, 19.46028647, 18.22954934, 17.1958903 ,
#        21.60304218, 14.71901407, 16.29205532, 12.36432281, 19.98831261,
#        15.37556411, 13.96678297, 10.06809496, 20.97197274,  7.45877832])

# %% [markdown]
# #Calculating the Mean Squared Error and R2_Score

# %%
from sklearn.metrics import mean_squared_error,r2_score
mse=mean_squared_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)
print("Mean Squared Error =",mse)
print("r2_score =",r2)
# Out:
# Mean Squared Error = 1.9918855518287906
# r2_score = 0.8927605914615384

# %% [markdown]
# #Plotting the Linear Regression:Actual Sales vs Predicted Sales

# %%
import matplotlib.pyplot as plt
plt.scatter(y_test,y_pred,color="blue",label="Predicted line")
plt.plot([y_test.min(),y_test.max()],[y_test.min(),y_test.max()],color='red',label="Actual Line")
plt.xlabel("Actual Sales")
plt.ylabel("Predicted Sales")
plt.legend()
plt.show()
